# %%
from importlib import reload

import GradientBoostingImplementation as gb
reload(gb)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets
from sklearn import tree
from sklearn.metrics import r2_score
from sklearn import inspection

# %%
# make a dummy regression problem 
X, y = datasets.make_regression(n_features=2, n_samples=50)

# fit cc implementation
tree_m = gb.RegressionTree()
tree_m.fit(X, y)

tree_m.predict(X)[:10]
# Out:
# array([ 52.77752239,  52.77752239,  11.46262229,  11.46262229,
#        -21.93960131,  11.46262229,  52.77752239,  52.77752239,
#        -61.1746374 , -21.93960131])

# %%
# replicate with sklearn 
sk_tree = tree.DecisionTreeRegressor()
sk_tree.fit(X, y)
sk_tree.predict(X)[:10]
# Out:
# array([ 52.77752239,  52.77752239,  11.46262229,  11.46262229,
#        -21.93960131,  11.46262229,  52.77752239,  52.77752239,
#        -61.1746374 , -21.93960131])

# %%
plt.figure(figsize=(10,10)) # Resize figure
tree.plot_tree(sk_tree, filled=True)
plt.show()

# %%
chk=gb.TreeViz()

# %%
chk.get_variable_importance(tree_m.root, X, False)
# Out:
# 964.2399099964805
# [178.11349247]
# [193.84886643]
# [array([1336.2022689]), 0]

# %%
sk_tree.tree_.compute_feature_importances(normalize=False)
# Out:
# array([1336.2022689,    0.       ])

# %%
tree_m.root.right_branch.right_branch.value
# Out:
# -61.174637401518495
