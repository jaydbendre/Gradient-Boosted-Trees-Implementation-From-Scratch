# %%
import GradientBoostingImplementation as gb
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets
from sklearn import tree
from sklearn.metrics import r2_score
from sklearn import inspection

# %%
# make a dummy regression problem 
X, y = datasets.make_regression(n_features=2, n_samples=50)

# fit cc implementation
tree_m = gb.RegressionTree(max_depth=1, min_samples=2, loss_threshold=0.001, min_impurity=1e-7)
tree_m.fit(X, y)

tree_m.predict(X)
# Out:
# array([-36.14417827, -11.07249795,  12.0771976 ,  12.0771976 ,
#        -11.07249795, -11.07249795,  12.0771976 ,  12.0771976 ,
#         38.44951321,  38.44951321, -36.14417827,  12.0771976 ,
#        -36.14417827, -11.07249795,  38.44951321,  38.44951321,
#         12.0771976 , -11.07249795,  38.44951321, -11.07249795,
#        -36.14417827, -11.07249795,  38.44951321, -11.07249795,
#         12.0771976 , -11.07249795, -36.14417827, -11.07249795,
#        -11.07249795, -36.14417827,  12.0771976 ,  38.44951321,
#        -36.14417827, -11.07249795, -11.07249795,  12.0771976 ,
#        -11.07249795,  12.0771976 , -36.14417827, -11.07249795,
#         12.0771976 , -11.07249795,  12.0771976 , -11.07249795,
#        -11.07249795,  12.0771976 , -36.14417827, -11.07249795,
#        -11.07249795, -11.07249795])

# %%
# replicate with sklearn 
sk_tree = tree.DecisionTreeRegressor(max_depth=2)
sk_tree.fit(X, y)
sk_tree.predict(X)[:10]
# Out:
# array([ 30.61124294,  75.11928882,  30.61124294, -17.58690446,
#         30.61124294,  75.11928882, -17.58690446,  30.61124294,
#         75.11928882,  75.11928882])

# %%
plt.figure(figsize=(10,10)) # Resize figure
tree.plot_tree(sk_tree, filled=True)
plt.show()

# %%
tree_m.calc
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/kw/p5hd0t2s1r9by7by6z5ls5h40000gn/T/ipykernel_35825/2205935297.py in <module>
# ----> 1 tree_m.calc_var_imp()
#
# TypeError: calc_var_imp() missing 3 required positional arguments: 'root', 'tot_samples', and 'reduction'
